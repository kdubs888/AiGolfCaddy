# %%
# %pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.3.0a1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.0)
# Requirement already satisfied: torch>=1.13 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.1.2)
# Requirement already satisfied: cloudpickle in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pandas in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.8.2)
# Requirement already satisfied: opencv-python in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.9.0.80)
# Requirement already satisfied: pygame in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.15.1)
# Requirement already satisfied: psutil in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.1)
# Requirement already satisfied: rich in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (13.7.0)
# Requirement already satisfied: shimmy~=1.3.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pillow in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (10.2.0)
# Requirement already satisfied: autorom~=0.6.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: click in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.5.2)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.1)
# Requirement already satisfied: filelock in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.13.1)
# Requirement already satisfied: sympy in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.12)
# Requirement already satisfied: networkx in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2023.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.15.1)
# Requirement already satisfied: colorama in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from tqdm->stable-baselines3[extra]>=2.0.0a4) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (6.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\xi chen\anaconda3\envs\mlenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Function to check if a point is inside a polygon
def point_in_polygon(ptc, polygon):
    # Get the x and y coordinates of the point
    x, y = ptc

    # Initialize a flag to check if the point is inside the polygon
    inside = False

    # Take the first point in the polygon
    p1 = polygon[0]

    # Loop through each side of the polygon
    for i in range(1, len(polygon) + 1):
        # Take the next point in the polygon
        p2 = polygon[i % len(polygon)]

        # Check if the point is roughly at the same height as the current side
        if y > min(p1[1], p2[1]):

            # Check if the point is not too high above the side or too low below the side
            if y <= max(p1[1], p2[1]):

                # Check if the point is to the left of the rightmost point of the side
                if x <= max(p1[0], p2[0]):

                    # Calculate the x-coordinate where a line from the point intersects with the side
                    x_intersection = (y - p1[1]) * (p2[0] - p1[0]) / (p2[1] - p1[1]) + p1[0]

                    # Check if the point is on or to the left of the calculated x-coordinate
                    if p1[0] == p2[0] or x <= x_intersection:

                        # Flip the inside flag, indicating that the point is inside the polygon
                        inside = not inside

        # Move to the next side of the polygon
        p1 = p2

    # Return whether the point is inside the polygon or not
    return inside

# %%
import numpy as np
import math
import gymnasium as gym
from gymnasium import spaces

class GolfEnv(gym.Env):
  def __init__(self):
    #Define the size of the grid
    self.grid_width = 200
    self.grid_height = 300
    self.shot_counter = 0

    #Define the action space as a Box space
    self.action_space = spaces.Box(
        low=np.array([0, 0, 0]),  # Minimum values for direction, club-type and swing strength #######
        high=np.array([180, 12, 3]),  # Maximum values for direction, club-type and swing strength ########
        dtype=np.float32
    )

    #Define the observation space
    self.observation_space = spaces.Dict({
          'x':spaces.Discrete(self.grid_width),
          'y':spaces.Discrete(self.grid_height)
      })

    #ball position
    self.ball_position = {
      'x': 50,
      'y': 0,
    }
    #green position
    self.green_left_corner = [self.grid_width-20, self.grid_height-20]
    self.green_right_corner = [self.grid_width, self.grid_height]

    #creating a dictionary to convert club to distance
    self.club_distances = {
            0: 200,
            1: 180,
            2: 170,
            3: 160,
            4: 150,
            5: 145,
            6: 138,
            7: 127,
            8: 120,
            9: 110,
            10: 97,
            11: 85,
            12: 55,
        }

    self.swing_strength = { #######
            0: 0.25,
            1: 0.5,
            2: 0.75,
            3: 1,
         }


  def step(self, action):

    # Extract direction, club type, and swing strength from the action
    direction = action[0]
    club_type = int(action[1])
    swing_strength = int(action[2])
    print(swing_strength)

    # Use direction and scaled distance by swing strength to calculate the new position
    angle_rad = math.radians(direction)
    scaled_distance = self.club_distances[club_type] * self.swing_strength[swing_strength]  # Scale distance by swing strength ########
    delta_x = scaled_distance * math.cos(angle_rad)
    delta_y = scaled_distance * math.sin(angle_rad)

    # Calculate new position
    new_x = self.ball_position['x'] + delta_x
    new_y = self.ball_position['y'] + delta_y

    new_x = round(new_x)
    new_y = round(new_y)

    #sets the reward to 0
    reward = 0
    terminated=False
    truncated=False
    #checks if the ball position is in the observation space and if not it sets it to the closest edge
    if new_x>self.observation_space['x'].n:
      reward = reward-10
      new_x=self.observation_space['x'].n
    if new_x<0:
      reward = reward-10
      new_x=0
    if new_y>self.observation_space['y'].n:
      reward = reward-10
      new_y=self.observation_space['y'].n

    #sets the ball position to the new position
    self.ball_position['x']=new_x
    self.ball_position['y']=new_y

    #checks if the ball position is on the green
    if (self.green_left_corner[0]<=self.ball_position['x']>=self.green_right_corner[0]) and (self.green_left_corner[1]<=self.ball_position['y']>=self.green_right_corner[1]):
      #print("You have made it the to green in {} hits".format(shots))
      # update on when the ball has made it to the green and the numbers of steps that it took

      reward=10
      terminated = True

    bunker = [(25, 53), (26, 42), (36, 34), (49, 33), (56, 44), (78, 95), (86, 138), (86, 45), (78, 147), (67, 142), (62, 148), (60, 176), (42, 186), (31, 176), (29, 168), (30, 150), (57, 180), (58, 111), (29, 60)]

    ptc = (self.ball_position['x'], self.ball_position['y'])

    if point_in_polygon(ptc, bunker):
      reward=10

    #adds a shot to the shot counter
    self.shot_counter+=1

    #limit to 10 shots per round
    if self.shot_counter>=10:
      truncated=True

    observation = {
        'x': self.ball_position['x'],
        'y': self.ball_position['y']
    }

    return observation, reward, terminated, truncated, {}

  def reset(self, seed=None, options=None):
    #sets ball position to the middle of the start of the hole
    self.ball_position = {
        'x': 50,
        'y': 0,
    }

    observation = {
        'x': self.ball_position['x'],
        'y': self.ball_position['y']
    }

    return observation, {}

# %%
from stable_baselines3.common.env_checker import check_env

# %%
env = GolfEnv()
check_env(env, warn=True)
# Out:
# 0
# 0
# 2
# 2
# 0
# 2
# 1
# 0
# 2
# 2
# 2
# c:\Users\Xi Chen\anaconda3\envs\mlenv\Lib\site-packages\stable_baselines3\common\env_checker.py:441: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
golf_env = GolfEnv()

golf_env.ball_position = {'x': 40, 'y': 40}

# Define an action (example: direction=90, club_type=5, strnght=3)
action = np.array([90, 5, 3])

# Call the step method to simulate the shot
observation, reward, terminated, truncated, _ = golf_env.step(action)

# Check if the ball is in the bunker based on the reward
if reward == 10:
    print("The ball is in the bunker!")
else:
    print("The ball is not in the bunker.")

# Print the final ball position
print("Final Ball Position:", golf_env.ball_position)
# Out:
# 3
# The ball is not in the bunker.
# Final Ball Position: {'x': 40, 'y': 185}

# %% [markdown]
# **Traning the Model**

# %%
env = GolfEnv()
check_env(env)

print(env.observation_space)
print(env.action_space.sample())
# Out:
# 0
# 2
# 1
# 0
# 1
# 0
# 0
# 1
# 1
# 2
# 0
# Dict('x': Discrete(200), 'y': Discrete(300))
# [25.691448   3.733479   2.3286211]

# %%
#from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, A2C, DQN, HerReplayBuffer, SAC 

from stable_baselines3.common.env_util import make_vec_env

# %%
vec_env = make_vec_env(GolfEnv, n_envs=1)

model = SAC("MultiInputPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=10000)
# Out:
# 2
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 707      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4        |
# ---------------------------------
# 0
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 914      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8        |
# ---------------------------------
# 0
# 1
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.833   |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 749      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 12       |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.625   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 892      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 16       |
# ---------------------------------
# 0
# 2
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.5     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 817      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 20       |
# ---------------------------------
# 0
# 2
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.417   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 923      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 24       |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -1.07    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 858      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 28       |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.938   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 980      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 32       |
# ---------------------------------
# 2
# 0
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -1.11    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 964      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 36       |
# ---------------------------------
# 2
# 2
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -1.25    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 983      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 40       |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.909   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 1081     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 44       |
# ---------------------------------
# 0
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.833   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 980      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 48       |
# ---------------------------------
# 0
# 0
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.577   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 1031     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 52       |
# ---------------------------------
# 0
# 0
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.536   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 1110     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 56       |
# ---------------------------------
# 1
# 1
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.667   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 1022     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 60       |
# ---------------------------------
# 2
# 2
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.781   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 980      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.882   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 991      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 68       |
# ---------------------------------
# 1
# 0
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.972   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 994      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 72       |
# ---------------------------------
# 0
# 2
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.789   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 1035     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 76       |
# ---------------------------------
# 2
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.75    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1090     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 80       |
# ---------------------------------
# 2
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.714   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 1031     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 84       |
# ---------------------------------
# 2
# 1
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.682   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1054     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 88       |
# ---------------------------------
# 2
# 2
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.761   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1102     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 92       |
# ---------------------------------
# 2
# 1
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.833   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1072     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# 0
# 1
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.9     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1117     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100      |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.9     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 414      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 104      |
# | train/             |          |
# |    actor_loss      | -2.08    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.999    |
# |    ent_coef_loss   | -0.00302 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3        |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.8     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 249      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.998    |
# |    ent_coef_loss   | -0.0091  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7        |
# ---------------------------------
# 2
# 2
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.7     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 191      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 112      |
# | train/             |          |
# |    actor_loss      | -2.08    |
# |    critic_loss     | 19.4     |
# |    ent_coef        | 0.997    |
# |    ent_coef_loss   | -0.015   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11       |
# ---------------------------------
# 0
# 0
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.8     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 158      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 116      |
# | train/             |          |
# |    actor_loss      | -2.14    |
# |    critic_loss     | 20.5     |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.021   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15       |
# ---------------------------------
# 2
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.7     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 138      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.995    |
# |    ent_coef_loss   | -0.0272  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19       |
# ---------------------------------
# 1
# 1
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.8     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 123      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -2.26    |
# |    critic_loss     | 24.2     |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0333  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23       |
# ---------------------------------
# 0
# 0
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.7     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 109      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.992    |
# |    ent_coef_loss   | -0.0394  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27       |
# ---------------------------------
# 1
# 2
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.6     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 100      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 132      |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 24.3     |
# |    ent_coef        | 0.991    |
# |    ent_coef_loss   | -0.0453  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31       |
# ---------------------------------
# 2
# 2
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.5     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 92       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | -2.42    |
# |    critic_loss     | 22.2     |
# |    ent_coef        | 0.99     |
# |    ent_coef_loss   | -0.0514  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35       |
# ---------------------------------
# 2
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.4     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 85       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 140      |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 22.9     |
# |    ent_coef        | 0.989    |
# |    ent_coef_loss   | -0.0578  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39       |
# ---------------------------------
# 1
# 0
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.4     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 80       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -2.59    |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.987    |
# |    ent_coef_loss   | -0.0635  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43       |
# ---------------------------------
# 1
# 2
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 77       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 148      |
# | train/             |          |
# |    actor_loss      | -2.68    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.986    |
# |    ent_coef_loss   | -0.0698  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47       |
# ---------------------------------
# 1
# 2
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.5     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 72       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.985    |
# |    ent_coef_loss   | -0.0756  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51       |
# ---------------------------------
# 0
# 2
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.4     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 69       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -2.9     |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.984    |
# |    ent_coef_loss   | -0.0819  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55       |
# ---------------------------------
# 0
# 0
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.4     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 67       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -3.09    |
# |    critic_loss     | 19.2     |
# |    ent_coef        | 0.983    |
# |    ent_coef_loss   | -0.0876  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59       |
# ---------------------------------
# 0
# 2
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.3     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 64       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -3.24    |
# |    critic_loss     | 22.7     |
# |    ent_coef        | 0.982    |
# |    ent_coef_loss   | -0.0939  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63       |
# ---------------------------------
# 1
# 1
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.3     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 63       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 168      |
# | train/             |          |
# |    actor_loss      | -3.39    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.98     |
# |    ent_coef_loss   | -0.0991  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67       |
# ---------------------------------
# 0
# 1
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.2     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 60       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -3.58    |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71       |
# ---------------------------------
# 1
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.3     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 59       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.978    |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75       |
# ---------------------------------
# 1
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.3     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 58       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -3.9     |
# |    critic_loss     | 17.2     |
# |    ent_coef        | 0.977    |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79       |
# ---------------------------------
# 1
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.3     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 57       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 184      |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.976    |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83       |
# ---------------------------------
# 0
# 2
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.1     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 55       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 188      |
# | train/             |          |
# |    actor_loss      | -4.08    |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.975    |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87       |
# ---------------------------------
# 0
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 54       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | -4.23    |
# |    critic_loss     | 20.7     |
# |    ent_coef        | 0.973    |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91       |
# ---------------------------------
# 0
# 2
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.2      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 53       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 196      |
# | train/             |          |
# |    actor_loss      | -4.31    |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.972    |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95       |
# ---------------------------------
# 1
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.3      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 53       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -4.41    |
# |    critic_loss     | 16.5     |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# 2
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.4      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 52       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 204      |
# | train/             |          |
# |    actor_loss      | -4.43    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 103      |
# ---------------------------------
# 2
# 0
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.3      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 51       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 208      |
# | train/             |          |
# |    actor_loss      | -4.42    |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.969    |
# |    ent_coef_loss   | -0.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107      |
# ---------------------------------
# 0
# 2
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.3      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 50       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 212      |
# | train/             |          |
# |    actor_loss      | -4.54    |
# |    critic_loss     | 18.7     |
# |    ent_coef        | 0.968    |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111      |
# ---------------------------------
# 0
# 2
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.4      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 49       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 216      |
# | train/             |          |
# |    actor_loss      | -4.53    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.967    |
# |    ent_coef_loss   | -0.149   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115      |
# ---------------------------------
# 0
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.4      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 48       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 220      |
# | train/             |          |
# |    actor_loss      | -4.6     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.966    |
# |    ent_coef_loss   | -0.152   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119      |
# ---------------------------------
# 0
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 48       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 224      |
# | train/             |          |
# |    actor_loss      | -4.54    |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.965    |
# |    ent_coef_loss   | -0.159   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123      |
# ---------------------------------
# 0
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 47       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 228      |
# | train/             |          |
# |    actor_loss      | -4.57    |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.964    |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127      |
# ---------------------------------
# 0
# 0
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 47       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 232      |
# | train/             |          |
# |    actor_loss      | -4.49    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 131      |
# ---------------------------------
# 1
# 2
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 46       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 236      |
# | train/             |          |
# |    actor_loss      | -4.51    |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.962    |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135      |
# ---------------------------------
# 1
# 0
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 46       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 240      |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.961    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 139      |
# ---------------------------------
# 1
# 1
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 45       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 244      |
# | train/             |          |
# |    actor_loss      | -4.43    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.96     |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 143      |
# ---------------------------------
# 0
# 0
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 44       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 248      |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 16.5     |
# |    ent_coef        | 0.958    |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 147      |
# ---------------------------------
# 0
# 2
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 44       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 252      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151      |
# ---------------------------------
# 0
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 43       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 256      |
# | train/             |          |
# |    actor_loss      | -4.48    |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.956    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 155      |
# ---------------------------------
# 1
# 1
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 43       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 260      |
# | train/             |          |
# |    actor_loss      | -4.48    |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.955    |
# |    ent_coef_loss   | -0.203   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 159      |
# ---------------------------------
# 0
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 42       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 264      |
# | train/             |          |
# |    actor_loss      | -4.53    |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.954    |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 163      |
# ---------------------------------
# 0
# 0
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 42       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 268      |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 8.08     |
# |    ent_coef        | 0.953    |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 167      |
# ---------------------------------
# 1
# 1
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1.1      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 42       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 272      |
# | train/             |          |
# |    actor_loss      | -4.38    |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 171      |
# ---------------------------------
# 1
# 2
# 2
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1.2      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 42       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 276      |
# | train/             |          |
# |    actor_loss      | -4.35    |
# |    critic_loss     | 12.8     |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.222   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175      |
# ---------------------------------
# 0
# 0
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1.2      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 41       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 280      |
# | train/             |          |
# |    actor_loss      | -4.46    |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.95     |
# |    ent_coef_loss   | -0.233   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 179      |
# ---------------------------------
# 1
# 1
# 1
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1.2      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 41       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 284      |
# | train/             |          |
# |    actor_loss      | -4.43    |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.949    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183      |
# ---------------------------------
# 0
# 1
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 41       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 288      |
# | train/             |          |
# |    actor_loss      | -4.48    |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187      |
# ---------------------------------
# 1
# 1
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 41       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 292      |
# | train/             |          |
# |    actor_loss      | -4.36    |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.947    |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 191      |
# ---------------------------------
# 1
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 296      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -0.254   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 195      |
# ---------------------------------
# 2
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 300      |
# | train/             |          |
# |    actor_loss      | -4.46    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.944    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 199      |
# ---------------------------------
# 1
# 2
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.9      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 304      |
# | train/             |          |
# |    actor_loss      | -4.57    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.943    |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 203      |
# ---------------------------------
# 0
# 0
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 308      |
# | train/             |          |
# |    actor_loss      | -4.57    |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.942    |
# |    ent_coef_loss   | -0.266   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207      |
# ---------------------------------
# 0
# 0
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.9      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 312      |
# | train/             |          |
# |    actor_loss      | -4.34    |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211      |
# ---------------------------------
# 0
# 0
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.9      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 39       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 316      |
# | train/             |          |
# |    actor_loss      | -4.39    |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 215      |
# ---------------------------------
# 2
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 39       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 320      |
# | train/             |          |
# |    actor_loss      | -4.29    |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.939    |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 219      |
# ---------------------------------
# 1
# 2
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 39       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 324      |
# | train/             |          |
# |    actor_loss      | -4.32    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.294   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223      |
# ---------------------------------
# 0
# 2
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 39       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 328      |
# | train/             |          |
# |    actor_loss      | -4.36    |
# |    critic_loss     | 11.3     |
# |    ent_coef        | 0.937    |
# |    ent_coef_loss   | -0.299   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227      |
# ---------------------------------
# 1
# 2
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 39       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 332      |
# | train/             |          |
# |    actor_loss      | -4.35    |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | -0.299   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231      |
# ---------------------------------
# 1
# 0
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 38       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 336      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 8.55     |
# |    ent_coef        | 0.935    |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235      |
# ---------------------------------
# 2
# 0
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.8      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 38       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 340      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 8.63     |
# |    ent_coef        | 0.934    |
# |    ent_coef_loss   | -0.321   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 239      |
# ---------------------------------
# 2
# 1
# 0
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 38       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 344      |
# | train/             |          |
# |    actor_loss      | -4.35    |
# |    critic_loss     | 8.7      |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.328   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243      |
# ---------------------------------
# 0
# 1
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 38       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 348      |
# | train/             |          |
# |    actor_loss      | -4.34    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.931    |
# |    ent_coef_loss   | -0.334   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 247      |
# ---------------------------------
# 2
# 1
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 38       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 352      |
# | train/             |          |
# |    actor_loss      | -4.18    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.333   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 251      |
# ---------------------------------
# 2
# 1
# 1
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 38       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 356      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 9.74     |
# |    ent_coef        | 0.929    |
# |    ent_coef_loss   | -0.331   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255      |
# ---------------------------------
# 1
# 1
# 0
# 2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 37       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 360      |
# | train/             |          |
# |    actor_loss      | -4.39    |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.928    |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259      |
# ---------------------------------
# 1
# 0
# 2
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.7      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 37       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 364      |
# | train/             |          |
# |    actor_loss      | -4.49    |
# |    critic_loss     | 6.62     |
# |    ent_coef        | 0.927    |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263      |
# ---------------------------------
# 0
# 2
# 2
# 0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.5      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 37       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 368      |
# | train/             |          |
# |    actor_loss      | -4.4     |
# |    critic_loss     | 7.14     |
# |    ent_coef        | 0.926    |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267      |
# ---------------------------------
# 1
# 2
# 0
# 0
# ...
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.0574  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9791     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9896     |
# |    fps             | 25       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 9896     |
# | train/             |          |
# |    actor_loss      | -9.77    |
# |    critic_loss     | 4.67     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9795     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9900     |
# |    fps             | 25       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 4.31     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.049   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9799     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9904     |
# |    fps             | 25       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 9904     |
# | train/             |          |
# |    actor_loss      | -9.82    |
# |    critic_loss     | 5.45     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.0581  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9803     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9908     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9908     |
# | train/             |          |
# |    actor_loss      | -9.99    |
# |    critic_loss     | 5.14     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0579   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9807     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9912     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9912     |
# | train/             |          |
# |    actor_loss      | -9.91    |
# |    critic_loss     | 5.22     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.0255  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9811     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9916     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9916     |
# | train/             |          |
# |    actor_loss      | -9.97    |
# |    critic_loss     | 4.64     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0152   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9815     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9920     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 5.29     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.028   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9819     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9924     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9924     |
# | train/             |          |
# |    actor_loss      | -9.78    |
# |    critic_loss     | 4.46     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.00215 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9823     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9928     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9928     |
# | train/             |          |
# |    actor_loss      | -9.84    |
# |    critic_loss     | 4.65     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0603   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9827     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 9.9      |
# | time/              |          |
# |    episodes        | 9932     |
# |    fps             | 25       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 9932     |
# | train/             |          |
# |    actor_loss      | -9.89    |
# |    critic_loss     | 4.59     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9831     |
# ---------------------------------
# 1
# 1
# 0
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9936     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9936     |
# | train/             |          |
# |    actor_loss      | -9.82    |
# |    critic_loss     | 4.42     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9835     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9940     |
# | train/             |          |
# |    actor_loss      | -9.82    |
# |    critic_loss     | 4.22     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0233   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9839     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9944     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9944     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 4.9      |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0645   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9843     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9948     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9948     |
# | train/             |          |
# |    actor_loss      | -9.69    |
# |    critic_loss     | 5.18     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.128    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9847     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9952     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9952     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 4.82     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0501   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9851     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9956     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9956     |
# | train/             |          |
# |    actor_loss      | -9.87    |
# |    critic_loss     | 5.6      |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.0216  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9855     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 25       |
# |    time_elapsed    | 392      |
# |    total_timesteps | 9960     |
# | train/             |          |
# |    actor_loss      | -9.51    |
# |    critic_loss     | 5.34     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | 0.0317   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9859     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9964     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9964     |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 4.67     |
# |    ent_coef        | 0.469    |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9863     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9968     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9968     |
# | train/             |          |
# |    actor_loss      | -9.93    |
# |    critic_loss     | 4.46     |
# |    ent_coef        | 0.469    |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9867     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9972     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9972     |
# | train/             |          |
# |    actor_loss      | -9.86    |
# |    critic_loss     | 4.3      |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | 0.117    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9871     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9976     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9976     |
# | train/             |          |
# |    actor_loss      | -9.86    |
# |    critic_loss     | 4.06     |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | 0.115    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9875     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9980     |
# | train/             |          |
# |    actor_loss      | -9.92    |
# |    critic_loss     | 4.99     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | -0.0227  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9879     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9984     |
# |    fps             | 25       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 9984     |
# | train/             |          |
# |    actor_loss      | -9.79    |
# |    critic_loss     | 4.57     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | -0.082   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9883     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9988     |
# |    fps             | 25       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 9988     |
# | train/             |          |
# |    actor_loss      | -9.84    |
# |    critic_loss     | 5.65     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | 0.0777   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9887     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9992     |
# |    fps             | 25       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 9992     |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 4.23     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | -0.0222  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9891     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 9996     |
# |    fps             | 25       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 9996     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 5.52     |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -0.0033  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9895     |
# ---------------------------------
# 1
# 1
# 1
# 1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 25       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -9.76    |
# |    critic_loss     | 4.04     |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | 0.0442   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------

# %% [markdown]
# ***Testing The Model***

# %%
from collections import OrderedDict

x_data = np.array([55], dtype=np.int64)
y_data = np.array([56], dtype=np.int64)
# calling x_data, and y_data to start off the golf ball

obs = OrderedDict([('x', x_data), ('y', y_data)])
# setting the obs to a data type that the model can take, and learn from

action, _ = model.predict(obs, deterministic=True)
# calling the models' next steps with the inital starting point

# %%
vec_env.reset()
# reseting the vec_env before the 

obs, reward, done, info = vec_env.step(action)
# running the next step of the model
# if you want to see the next step, then call the vec_env.step(action) again
# should run until the ten steps, and then the model should stop 

print(obs)
# OrderedDict([('x', array([49], dtype=int64)), ('y', array([69], dtype=int64))])
# the arrays for the x, and y are the hits that the algorithm is taking
# Out:
# 1
# OrderedDict([('x', array([50], dtype=int64)), ('y', array([69], dtype=int64))])
